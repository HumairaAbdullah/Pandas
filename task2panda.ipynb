# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
data=pd.read_csv('C:\\Users\\DevValley\\Downloads\\retail_store_sales.csv')

# %%
data
# Out:
#       Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0        TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1        TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2        TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3        TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4        TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
# ...              ...         ...            ...           ...             ...
# 12570    TXN_9347481     CUST_18     Patisserie   Item_23_PAT            38.0
# 12571    TXN_4009414     CUST_03      Beverages    Item_2_BEV             6.5
# 12572    TXN_5306010     CUST_11       Butchers    Item_7_BUT            14.0
# 12573    TXN_5167298     CUST_04      Furniture    Item_7_FUR            14.0
# 12574    TXN_2407494     CUST_23           Food   Item_9_FOOD            17.0
#
# ...

# %%
data.isnull().values.sum()
# Out:
# np.int64(7229)

# %%
missing_column=data.columns[data.isnull().sum()>0]

# %%
missing_column
# Out:
# Index(['Item', 'Price Per Unit', 'Quantity', 'Total Spent',
#        'Discount Applied'],
#       dtype='object')

# %%
nullval=data.isnull().any(axis=0)

# %%
nullval
# Out:
# Transaction ID      False
# Customer ID         False
# Category            False
# Item                 True
# Price Per Unit       True
# Quantity             True
# Total Spent          True
# Payment Method      False
# Location            False
# Transaction Date    False
# Discount Applied     True
# dtype: bool

# %%
#find percentage of the null values 
data.isnull().sum()/len(data)*100
# Out:
# Transaction ID       0.000000
# Customer ID          0.000000
# Category             0.000000
# Item                 9.646123
# Price Per Unit       4.842942
# Quantity             4.803181
# Total Spent          4.803181
# Payment Method       0.000000
# Location             0.000000
# Transaction Date     0.000000
# Discount Applied    33.391650
# dtype: float64

# %%
data.fillna('HUMAIRA')
# Out:
#       Transaction ID Customer ID       Category          Item Price Per Unit  \
# 0        TXN_6867343     CUST_09     Patisserie   Item_10_PAT           18.5
# 1        TXN_3731986     CUST_22  Milk Products  Item_17_MILK           29.0
# 2        TXN_9303719     CUST_02       Butchers   Item_12_BUT           21.5
# 3        TXN_9458126     CUST_06      Beverages   Item_16_BEV           27.5
# 4        TXN_4575373     CUST_05           Food   Item_6_FOOD           12.5
# ...              ...         ...            ...           ...            ...
# 12570    TXN_9347481     CUST_18     Patisserie   Item_23_PAT           38.0
# 12571    TXN_4009414     CUST_03      Beverages    Item_2_BEV            6.5
# 12572    TXN_5306010     CUST_11       Butchers    Item_7_BUT           14.0
# 12573    TXN_5167298     CUST_04      Furniture    Item_7_FUR           14.0
# 12574    TXN_2407494     CUST_23           Food   Item_9_FOOD           17.0
#
# ...

# %%
fillnullinitem=data['Item'].fillna('Humaira')

# %%
fillnullinitem
# Out:
# 0         Item_10_PAT
# 1        Item_17_MILK
# 2         Item_12_BUT
# 3         Item_16_BEV
# 4         Item_6_FOOD
#              ...
# 12570     Item_23_PAT
# 12571      Item_2_BEV
# 12572      Item_7_BUT
# 12573      Item_7_FUR
# 12574     Item_9_FOOD
# Name: Item, Length: 12575, dtype: object

# %%
data['Quantity'].fillna('no value exists')
# Out:
# 0        10.0
# 1         9.0
# 2         2.0
# 3         9.0
# 4         7.0
#          ...
# 12570     4.0
# 12571     9.0
# 12572    10.0
# 12573     6.0
# 12574     3.0
# Name: Quantity, Length: 12575, dtype: object

# %%
data['Discount Applied'].fillna('No Discounts')
# Out:
# 0                True
# 1                True
# 2               False
# 3        No Discounts
# 4               False
#              ...
# 12570    No Discounts
# 12571           False
# 12572    No Discounts
# 12573            True
# 12574    No Discounts
# Name: Discount Applied, Length: 12575, dtype: object

# %%
data.fillna({'Item':'no item found','Quantity':'no quantity ','Total Spent':'no spent','Discount Applied':'0%'})
# Out:
#       Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0        TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1        TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2        TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3        TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4        TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
# ...              ...         ...            ...           ...             ...
# 12570    TXN_9347481     CUST_18     Patisserie   Item_23_PAT            38.0
# 12571    TXN_4009414     CUST_03      Beverages    Item_2_BEV             6.5
# 12572    TXN_5306010     CUST_11       Butchers    Item_7_BUT            14.0
# 12573    TXN_5167298     CUST_04      Furniture    Item_7_FUR            14.0
# 12574    TXN_2407494     CUST_23           Food   Item_9_FOOD            17.0
#
# ...

# %%
data['Transaction ID'].unique()
# Out:
# array(['TXN_6867343', 'TXN_3731986', 'TXN_9303719', ..., 'TXN_5306010',
#        'TXN_5167298', 'TXN_2407494'], dtype=object)

# %%
data['Transaction ID'].duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12570    False
# 12571    False
# 12572    False
# 12573    False
# 12574    False
# Name: Transaction ID, Length: 12575, dtype: bool

# %%
data['Transaction ID'].is_unique
# Out:
# True

# %%
data['Transaction ID'].duplicated().sum()
# Out:
# np.int64(0)

# %%
data['Transaction ID'].duplicated().any()
# Out:
# np.False_

# %%
#it will go through to the all rows of the dataFrame
data.duplicated().any()
# Out:
# np.False_

# %%
data['Check']=data['Price Per Unit']*data['Quantity']

# %%
data['Flag']=data['Check']!=data['Total Spent']

# %%
data
# Out:
#       Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0        TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1        TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2        TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3        TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4        TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
# ...              ...         ...            ...           ...             ...
# 12570    TXN_9347481     CUST_18     Patisserie   Item_23_PAT            38.0
# 12571    TXN_4009414     CUST_03      Beverages    Item_2_BEV             6.5
# 12572    TXN_5306010     CUST_11       Butchers    Item_7_BUT            14.0
# 12573    TXN_5167298     CUST_04      Furniture    Item_7_FUR            14.0
# 12574    TXN_2407494     CUST_23           Food   Item_9_FOOD            17.0
#
# ...

# %%
#import numpy as np

# %%
d1={'FRUITS':['Grapes','avacado','cherry','Mellbury','strawberies'],
   'QUANTIY':[10,20,30,40,50],
   'PRICE':[100,200,300,400,500]}

# %%
#from numpy import linalg

# %%
data=pd.DataFrame(d1)

# %%
data
# Out:
#         FRUITS  QUANTIY  PRICE
# 0       Grapes       10    100
# 1      avacado       20    200
# 2       cherry       30    300
# 3     Mellbury       40    400
# 4  strawberies       50    500

# %%
data.pivot(columns='FRUITS',values='QUANTIY',index='PRICE')
# Out:
# FRUITS  Grapes  Mellbury  avacado  cherry  strawberies
# PRICE
# 100       10.0       NaN      NaN     NaN          NaN
# 200        NaN       NaN     20.0     NaN          NaN
# 300        NaN       NaN      NaN    30.0          NaN
# 400        NaN      40.0      NaN     NaN          NaN
# 500        NaN       NaN      NaN     NaN         50.0

# %%
data.pivot_table(aggfunc='sum', index='FRUITS', values='QUANTIY',columns='PRICE',fill_value='not',margins=True, margins_name='Total') #,margins=True)
# Out:
# PRICE        100  200  300  400  500  Total
# FRUITS
# Grapes        10  not  not  not  not     10
# Mellbury     not  not  not   40  not     40
# avacado      not   20  not  not  not     20
# cherry       not  not   30  not  not     30
# strawberies  not  not  not  not   50     50
# Total         10   20   30   40   50    150

# %%
data.pivot_table(aggfunc='sum', index='FRUITS', values='QUANTIY',columns='PRICE',fill_value='not',margins_name='Total Quantity',margins=True)
# Out:
# PRICE           100  200  300  400  500  Total Quantity
# FRUITS
# Grapes           10  not  not  not  not              10
# Mellbury        not  not  not   40  not              40
# avacado         not   20  not  not  not              20
# cherry          not  not   30  not  not              30
# strawberies     not  not  not  not   50              50
# Total Quantity   10   20   30   40   50             150
